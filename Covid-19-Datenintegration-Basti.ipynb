# %% [markdown]
# # Covid-19 Data Science Project

# %% [markdown]
# Eine Datenanalyse zu Covid-19 Daten. Ziel dieser Datenanalyse ist es ein Modell zu entwickeln, dass die zukünftigen Fallzahlen anhand verschiedener Input-Variablen wie dem Standort, den aktuellen Maßnahmen (Lockdown) und den vorherigen Fallzahlen vorhersagen kann. Zur Analyse werden Regressionsmodelle verwendet. Anschließend wird ein Deep Learning Algorithmus (neuronales Netz) angewendet.

# %%
import io
import urllib
import datetime
from datetime import timedelta
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from progressbar import ProgressBar
import time

from datetime import datetime
import warnings
warnings.filterwarnings("ignore")
from wetterdienst.dwd.observations import DwdObservationRequest, DwdObservationPeriod, DwdObservationResolution, DwdObservationParameter, DwdObservationDataset

# %% [markdown]
# Historische Daten vom RKI zum Bundesland Baden-Württemberg.
#
# Spaltenbeschreibung: https://npgeo-corona-npgeo-de.hub.arcgis.com/datasets/dd4580c810204019a7b8eb3e0b329dd6_0
#
# Weitere Beschreibungen: https://www.bbsr.bund.de/BBSR/DE/forschung/raumbeobachtung/InteraktiveAnwendungen/corona-dashboard/corona-dashboard_einstieg.html
#
# Berechnung der 7-Tage-Inzidenz mittels Meldedatum: https://lua.rlp.de/de/presse/detail/news/News/detail/corona-hinweise-zur-berechnung-der-7-tage-inzidenz/

# %%
# # Datendownload
# url_cases_rki = "https://opendata.arcgis.com/datasets/dd4580c810204019a7b8eb3e0b329dd6_0.csv?where=IdBundesland%20%3E%3D%208%20AND%20IdBundesland%20%3C%3D%208"
# filename_cases = "./RKI_daily.csv"

# urllib.request.urlretrieve(url_cases_rki, filename_cases)

# %%
data_all = pd.read_csv("./RKI_daily.csv")

# %%
# data_all["Altersgruppe"].unique()

data_all = data_all.sort_values(by=['Landkreis','Meldedatum'])\
            .drop(["ObjectId", "IdBundesland", "Bundesland", "Altersgruppe2", "AnzahlTodesfall", "Geschlecht",\
                    "NeuerFall", "NeuerTodesfall", "Refdatum", "NeuGenesen", "IstErkrankungsbeginn"], axis=1)

mask_age = (data_all["Altersgruppe"] == "A60-A79") | (data_all["Altersgruppe"] == "A80+")
data_all["AnzahlFall>59"] = 0
data_all["AnzahlFall>59"][mask_age] = data_all["AnzahlFall"]
# Alternativ new column mit numpy.where erstellen

# %%
anzahl_faelle = data_all["AnzahlFall"].sum()
data_all
# Out:
#                  Landkreis Altersgruppe  AnzahlFall              Meldedatum  \
# 183523  LK Alb-Donau-Kreis      A35-A59           1  2020/02/28 00:00:00+00
# 181105  LK Alb-Donau-Kreis      A15-A34           1  2020/03/04 00:00:00+00
# 183524  LK Alb-Donau-Kreis      A35-A59           1  2020/03/04 00:00:00+00
# 183525  LK Alb-Donau-Kreis      A35-A59           1  2020/03/04 00:00:00+00
# 183526  LK Alb-Donau-Kreis      A35-A59           1  2020/03/07 00:00:00+00
# ...                    ...          ...         ...                     ...
# 177559              SK Ulm      A05-A14           2  2021/03/18 00:00:00+00
# 179542              SK Ulm      A15-A34           2  2021/03/18 00:00:00+00
# 180404              SK Ulm      A60-A79           1  2021/03/18 00:00:00+00
# 180601              SK Ulm      A60-A79           1  2021/03/18 00:00:00+00
# 181832              SK Ulm      A35-A59           2  2021/03/18 00:00:00+00
#
#         IdLandkreis             Datenstand  AnzahlGenesen  AnzahlFall>59
# 183523         8425  19.03.2021, 00:00 Uhr              1              0
# 181105         8425  19.03.2021, 00:00 Uhr              1              0
# 183524         8425  19.03.2021, 00:00 Uhr              1              0
# 183525         8425  19.03.2021, 00:00 Uhr              1              0
# 183526         8425  19.03.2021, 00:00 Uhr              1              0
# ...             ...                    ...            ...            ...
# 177559         8421  19.03.2021, 00:00 Uhr              0              0
# 179542         8421  19.03.2021, 00:00 Uhr              0              0
# 180404         8421  19.03.2021, 00:00 Uhr              0              1
# 180601         8421  19.03.2021, 00:00 Uhr              0              1
# 181832         8421  19.03.2021, 00:00 Uhr              0              0
#
# [199520 rows x 8 columns]

# %%
data_all["Meldedatum"] = data_all["Meldedatum"].str.slice(stop=10)
data_all["Meldedatum"] = pd.to_datetime(data_all["Meldedatum"], format='%Y/%m/%d') #- pd.to_timedelta(7, unit='d')

# %%
landkreise_id = data_all[["Landkreis", "IdLandkreis"]].drop_duplicates()

# %%
data_all = data_all.groupby(['IdLandkreis', pd.Grouper(key='Meldedatum', freq='W-FRI', label="right")])['AnzahlFall', "AnzahlGenesen", "AnzahlFall>59"]\
       .sum()\
       .reset_index()\
       .sort_values(['IdLandkreis', 'Meldedatum'])

data_all['Meldedatum'] = data_all['Meldedatum'] + timedelta(days=1)

# %%
data_all = data_all.merge(landkreise_id, left_on='IdLandkreis', right_on='IdLandkreis')
data_all
# Out:
#       IdLandkreis Meldedatum  AnzahlFall  AnzahlGenesen  AnzahlFall>59  \
# 0            8111 2020-03-07           5              5              0
# 1            8111 2020-03-14          78             78              3
# 2            8111 2020-03-21         310            303             41
# 3            8111 2020-03-28         275            261             65
# 4            8111 2020-04-04         237            225             65
# ...           ...        ...         ...            ...            ...
# 2345         8437 2021-02-20          40             40             11
# 2346         8437 2021-02-27          80             78             14
# 2347         8437 2021-03-06         108             96             19
# 2348         8437 2021-03-13         161             37             22
# 2349         8437 2021-03-20         143              1             22
#
#            Landkreis
# 0       SK Stuttgart
# 1       SK Stuttgart
# 2       SK Stuttgart
# 3       SK Stuttgart
# 4       SK Stuttgart
# ...              ...
# 2345  LK Sigmaringen
# 2346  LK Sigmaringen
# 2347  LK Sigmaringen
# 2348  LK Sigmaringen
# 2349  LK Sigmaringen
#
# [2350 rows x 6 columns]

# %%
print("Anzahl der Fälle stimmt noch überein? " + str(anzahl_faelle == data_all["AnzahlFall"].sum()))
# Out:
# Anzahl der Fälle stimmt noch überein? True

# %% [markdown]
# <br>
# Bevölkerungsentwicklung der Stadt- und Landkreise in Baden-Württemberg
# https://www.statistik-bw.de/BevoelkGebiet/Bevoelkerung/01035055.tab?R=LA
#
# Bevölkerungsdichte der Stadt- und Landkreise in Baden-Württemberg
# https://www.statistik-bw.de/BevoelkGebiet/Bevoelkerung/01515020.tab?R=LA

# %%
data_inhab = pd.read_csv("https://www.statistik-bw.de/BevoelkGebiet/Bevoelk_I_D_A_vj.csv",
                 encoding = "ISO-8859-1",
                 sep=";",
                 decimal=",",
                 skiprows=17)
data_inhab = data_inhab[(data_inhab["Amtlicher Gemeindeschlüssel (AGS)"]>1000) &
                        (data_inhab["Amtlicher Gemeindeschlüssel (AGS)"]<10000) &
                        # (data_inhab["Bevölkerung insgesamt"].str.isnumeric())==True &
                        (data_inhab["Stichtag"] == "30.09.2020")]
                         
# Aktuellster Stichtag und alles nur Schätzungen. Also keine Differenzierung notwendig

# %%
data_inhab
# Out:
#      Kürzel der Regionaleinheit  Amtlicher Gemeindeschlüssel (AGS)  \
# 6989                         KR                               8111
# 6990                         KR                               8115
# 6991                         KR                               8116
# 6992                         KR                               8117
# 6993                         KR                               8118
# 6994                         KR                               8119
# 6995                         KR                               8121
# 6996                         KR                               8125
# 6997                         KR                               8126
# 6998                         KR                               8127
# 6999                         KR                               8128
# 7000                         KR                               8135
# 7001                         KR                               8136
# 7002                         KR                               8211
# 7003                         KR                               8212
# 7004                         KR                               8215
# 7005                         KR                               8216
# 7006                         KR                               8221
# 7007                         KR                               8222
# 7008                         KR                               8225
# 7009                         KR                               8226
# 7010                         KR                               8231
# 7011                         KR                               8235
# 7012                         KR                               8236
# 7013                         KR                               8237
# 7014                         KR                               8311
# 7015                         KR                               8315
# 7016                         KR                               8316
# 7017                         KR                               8317
# 7018                         KR                               8325
# 7019                         KR                               8326
# 7020                         KR                               8327
# 7021                         KR                               8335
# 7022                         KR                               8336
# 7023                         KR                               8337
# 7024                         KR                               8415
# 7025                         KR                               8416
# 7026                         KR                               8417
# 7027                         KR                               8421
# 7028                         KR                               8425
# 7029                         KR                               8426
# 7030                         KR                               8435
# 7031                         KR                               8436
# 7032                         KR                               8437
#
#                             Regionalname    Stichtag Bevölkerung insgesamt  \
# 6989                Stadtkreis Stuttgart  30.09.2020                631688
# 6990                 Landkreis Böblingen  30.09.2020                393609
# 6991                 Landkreis Esslingen  30.09.2020                534525
# 6992                 Landkreis Göppingen  30.09.2020                259076
# 6993               Landkreis Ludwigsburg  30.09.2020                545782
# 6994           Landkreis Rems-Murr-Kreis  30.09.2020                428007
# 6995                Stadtkreis Heilbronn  30.09.2020                126241
# 6996                 Landkreis Heilbronn  30.09.2020                346652
# 6997            Landkreis Hohenlohekreis  30.09.2020                112964
# 6998           Landkreis Schwäbisch Hall  30.09.2020                197898
# 6999         Landkreis Main-Tauber-Kreis  30.09.2020                132691
# 7000                Landkreis Heidenheim  30.09.2020                132991
# 7001               Landkreis Ostalbkreis  30.09.2020                314471
# 7002              Stadtkreis Baden-Baden  30.09.2020                 55345
# 7003                Stadtkreis Karlsruhe  30.09.2020                308530
# 7004                 Landkreis Karlsruhe  30.09.2020                447120
# 7005                   Landkreis Rastatt  30.09.2020                232481
# 7006               Stadtkreis Heidelberg  30.09.2020                158852
# 7007                 Stadtkreis Mannheim  30.09.2020                310121
# 7008     Landkreis Neckar-Odenwald-Kreis  30.09.2020                144007
# 7009        Landkreis Rhein-Neckar-Kreis  30.09.2020                549080
# 7010                Stadtkreis Pforzheim  30.09.2020                126269
# 7011                      Landkreis Calw  30.09.2020                160208
# 7012                  Landkreis Enzkreis  30.09.2020                200005
# 7013              Landkreis Freudenstadt  30.09.2020                118502
# 7014     Stadtkreis Freiburg im Breisgau  30.09.2020                230023
# 7015  Landkreis Breisgau-Hochschwarzwald  30.09.2020                265123
# 7016               Landkreis Emmendingen  30.09.2020                166784
# 7017              Landkreis Ortenaukreis  30.09.2020                432413
# 7018                  Landkreis Rottweil  30.09.2020                140275
# 7019    Landkreis Schwarzwald-Baar-Kreis  30.09.2020                212981
# 7020                Landkreis Tuttlingen  30.09.2020                141565
# 7021                  Landkreis Konstanz  30.09.2020                286835
# 7022                   Landkreis Lörrach  30.09.2020                229341
# 7023                  Landkreis Waldshut  30.09.2020                171411
# 7024                Landkreis Reutlingen  30.09.2020                287445
# 7025                  Landkreis Tübingen  30.09.2020                227426
# 7026           Landkreis Zollernalbkreis  30.09.2020                189830
# 7027                      Stadtkreis Ulm  30.09.2020                126297
# 7028           Landkreis Alb-Donau-Kreis  30.09.2020                198275
# 7029                  Landkreis Biberach  30.09.2020                202322
# 7030             Landkreis Bodenseekreis  30.09.2020                218641
# 7031                Landkreis Ravensburg  30.09.2020                286240
# 7032               Landkreis Sigmaringen  30.09.2020                131154
#
#      Bevölkerung männlich Bevölkerung weiblich Deutsche zusammen  \
# 6989               315677               316011            474057
# 6990               195789               197820            319500
# 6991               266993               267532            439603
# 6992               129150               129926            214155
# 6993               270971               274811            445920
# 6994               211651               216356            358065
# 6995                63617                62624             92994
# 6996               174017               172635            294400
# 6997                56992                55972             99599
# 6998                99252                98646            173652
# 6999                66190                66501            119508
# 7000                66163                66828            111461
# 7001               156722               157749            278661
# 7002                26579                28766             44060
# 7003               157826               150704            251290
# 7004               222701               224419            384894
# 7005               115474               117007            198185
# 7006                76483                82369            128286
# 7007               154651               155470            235569
# 7008                72379                71628            128868
# 7009               270129               278951            477736
# 7010                62215                64054             91463
# 7011                80365                79843            134971
# 7012                99251               100754            172974
# 7013                59235                59267            103696
# 7014               109983               120040            190921
# 7015               130705               134418            232292
# 7016                82516                84268            148334
# 7017               215766               216647            378338
# 7018                70193                70082            123127
# 7019               105523               107458            178418
# 7020                71229                70336            116834
# 7021               139576               147259            242034
# 7022               112544               116797            193212
# 7023                85017                86394            143427
# 7024               142622               144823            241121
# 7025               111069               116357            196508
# 7026                94142                95688            164145
# 7027                62674                63623            100655
# 7028               100047                98228            170568
# 7029               101918               100404            179640
# 7030               107779               110862            187656
# 7031               142728               143512            252799
# 7032                65880                65274            116330
#
#      Deutsche männlich Deutsche weiblich Ausländer zusammen  \
# 6989            233142            240915             157631
# 6990            157258            162242              74109
# 6991            215137            224466              94922
# 6992            105076            109079              44921
# 6993            218034            227886              99862
# 6994            175040            183025              69942
# 6995             45529             47465              33247
# 6996            145993            148407              52252
# 6997             49667             49932              13365
# 6998             86061             87591              24246
# 6999             59097             60411              13183
# 7000             54621             56840              21530
# 7001            137720            140941              35810
# 7002             20959             23101              11285
# 7003            126437            124853              57240
# 7004            189359            195535              62226
# 7005             97568            100617              34296
# 7006             61155             67131              30566
# 7007            115063            120506              74552
# 7008             64139             64729              15139
# 7009            232941            244795              71344
# 7010             44443             47020              34806
# 7011             66876             68095              25237
# 7012             85040             87934              27031
# 7013             51388             52308              14806
# 7014             90028            100893              39102
# 7015            113223            119069              32831
# 7016             72565             75769              18450
# 7017            186677            191661              54075
# 7018             61151             61976              17148
# 7019             87278             91140              34563
# 7020             57985             58849              24731
# 7021            116528            125506              44801
# 7022             94167             99045              36129
# 7023             70515             72912              27984
# 7024            118124            122997              46324
# 7025             95225            101283              30918
# 7026             80441             83704              25685
# 7027             49021             51634              25642
# 7028             84837             85731              27707
# 7029             89404             90236              22682
# 7030             91897             95759              30985
# 7031            124070            128729              33441
# 7032             57648             58682              14824
#
#      Ausländer männlich Ausländer weiblich
# 6989              82535              75096
# 6990              38531              35578
# 6991              51856              43066
# 6992              24074              20847
# 6993              52937              46925
# 6994              36611              33331
# 6995              18088              15159
# 6996              28024              24228
# 6997               7325               6040
# 6998              13191              11055
# 6999               7093               6090
# 7000              11542               9988
# 7001              19002              16808
# 7002               5620               5665
# 7003              31389              25851
# 7004              33342              28884
# 7005              17906              16390
# 7006              15328              15238
# 7007              39588              34964
# 7008               8240               6899
# 7009              37188              34156
# 7010              17772              17034
# 7011              13489              11748
# 7012              14211              12820
# 7013               7847               6959
# 7014              19955              19147
# 7015              17482              15349
# 7016               9951               8499
# 7017              29089              24986
# 7018               9042               8106
# 7019              18245              16318
# 7020              13244              11487
# 7021              23048              21753
# 7022              18377              17752
# 7023              14502              13482
# 7024              24498              21826
# 7025              15844              15074
# 7026              13701              11984
# 7027              13653              11989
# 7028              15210              12497
# 7029              12514              10168
# 7030              15882              15103
# 7031              18658              14783
# 7032               8232               6592

# %%
data_inhab_perkm = pd.read_csv("https://www.statistik-bw.de/BevoelkGebiet/Bevoelk_I_Flaeche_j.csv",
                 encoding = "ISO-8859-1",
                 sep=";",
                 decimal=",",
                 skiprows=18)

# %%
data_inhab_perkm = data_inhab_perkm[(data_inhab_perkm["Amtlicher Gemeindeschlüssel (AGS)"]>1000) &
                        (data_inhab_perkm["Amtlicher Gemeindeschlüssel (AGS)"]<10000) &
                        (data_inhab_perkm["Stichtag"] == "31.12.2019")]
# Aktuellster Stichtag

# %%
data_inhab_perkm
# Out:
#      Kürzel der Regionaleinheit  Amtlicher Gemeindeschlüssel (AGS)  \
# 4665                         KR                               8111
# 4666                         KR                               8115
# 4667                         KR                               8116
# 4668                         KR                               8117
# 4669                         KR                               8118
# 4670                         KR                               8119
# 4671                         KR                               8121
# 4672                         KR                               8125
# 4673                         KR                               8126
# 4674                         KR                               8127
# 4675                         KR                               8128
# 4676                         KR                               8135
# 4677                         KR                               8136
# 4678                         KR                               8211
# 4679                         KR                               8212
# 4680                         KR                               8215
# 4681                         KR                               8216
# 4682                         KR                               8221
# 4683                         KR                               8222
# 4684                         KR                               8225
# 4685                         KR                               8226
# 4686                         KR                               8231
# 4687                         KR                               8235
# 4688                         KR                               8236
# 4689                         KR                               8237
# 4690                         KR                               8311
# 4691                         KR                               8315
# 4692                         KR                               8316
# 4693                         KR                               8317
# 4694                         KR                               8325
# 4695                         KR                               8326
# 4696                         KR                               8327
# 4697                         KR                               8335
# 4698                         KR                               8336
# 4699                         KR                               8337
# 4700                         KR                               8415
# 4701                         KR                               8416
# 4702                         KR                               8417
# 4703                         KR                               8421
# 4704                         KR                               8425
# 4705                         KR                               8426
# 4706                         KR                               8435
# 4707                         KR                               8436
# 4708                         KR                               8437
#
#      Postleitzahl                        Regionalname    Stichtag  \
# 4665            X                Stadtkreis Stuttgart  31.12.2019
# 4666            X                 Landkreis Böblingen  31.12.2019
# 4667            X                 Landkreis Esslingen  31.12.2019
# 4668            X                 Landkreis Göppingen  31.12.2019
# 4669            X               Landkreis Ludwigsburg  31.12.2019
# 4670            X           Landkreis Rems-Murr-Kreis  31.12.2019
# 4671            X                Stadtkreis Heilbronn  31.12.2019
# 4672            X                 Landkreis Heilbronn  31.12.2019
# 4673            X            Landkreis Hohenlohekreis  31.12.2019
# 4674            X           Landkreis Schwäbisch Hall  31.12.2019
# 4675            X         Landkreis Main-Tauber-Kreis  31.12.2019
# 4676            X                Landkreis Heidenheim  31.12.2019
# 4677            X               Landkreis Ostalbkreis  31.12.2019
# 4678            X              Stadtkreis Baden-Baden  31.12.2019
# 4679            X                Stadtkreis Karlsruhe  31.12.2019
# 4680            X                 Landkreis Karlsruhe  31.12.2019
# 4681            X                   Landkreis Rastatt  31.12.2019
# 4682            X               Stadtkreis Heidelberg  31.12.2019
# 4683            X                 Stadtkreis Mannheim  31.12.2019
# 4684            X     Landkreis Neckar-Odenwald-Kreis  31.12.2019
# 4685            X        Landkreis Rhein-Neckar-Kreis  31.12.2019
# 4686            X                Stadtkreis Pforzheim  31.12.2019
# 4687            X                      Landkreis Calw  31.12.2019
# 4688            X                  Landkreis Enzkreis  31.12.2019
# 4689            X              Landkreis Freudenstadt  31.12.2019
# 4690            X     Stadtkreis Freiburg im Breisgau  31.12.2019
# 4691            X  Landkreis Breisgau-Hochschwarzwald  31.12.2019
# 4692            X               Landkreis Emmendingen  31.12.2019
# 4693            X              Landkreis Ortenaukreis  31.12.2019
# 4694            X                  Landkreis Rottweil  31.12.2019
# 4695            X    Landkreis Schwarzwald-Baar-Kreis  31.12.2019
# 4696            X                Landkreis Tuttlingen  31.12.2019
# 4697            X                  Landkreis Konstanz  31.12.2019
# 4698            X                   Landkreis Lörrach  31.12.2019
# 4699            X                  Landkreis Waldshut  31.12.2019
# 4700            X                Landkreis Reutlingen  31.12.2019
# 4701            X                  Landkreis Tübingen  31.12.2019
# 4702            X           Landkreis Zollernalbkreis  31.12.2019
# 4703            X                      Stadtkreis Ulm  31.12.2019
# 4704            X           Landkreis Alb-Donau-Kreis  31.12.2019
# 4705            X                  Landkreis Biberach  31.12.2019
# 4706            X             Landkreis Bodenseekreis  31.12.2019
# 4707            X                Landkreis Ravensburg  31.12.2019
# 4708            X               Landkreis Sigmaringen  31.12.2019
#
#       Bevölkerung insgesamt  Gemeindegebiet ha  Bevölkerungsdichte EW/km²
# 4665                 635911              20733                       3067
# 4666                 392807              61776                        636
# 4667                 535024              64128                        834
# 4668                 258145              64234                        402
# 4669                 545423              68677                        794
# 4670                 427248              85808                        498
# 4671                 126592               9990                       1267
# 4672                 344456             109991                        313
# 4673                 112655              77676                        145
# 4674                 196761             148407                        133
# 4675                 132399             130412                        102
# 4676                 132777              62713                        212
# 4677                 314025             151139                        208
# 4678                  55185              14019                        394
# 4679                 312060              17342                       1799
# 4680                 445101             108498                        410
# 4681                 231420              73843                        313
# 4682                 161485              10883                       1484
# 4683                 310658              14497                       2143
# 4684                 143633             112595                        128
# 4685                 548355             106155                        517
# 4686                 125957               9799                       1285
# 4687                 159201              79729                        200
# 4688                 199556              57360                        348
# 4689                 118243              87040                        136
# 4690                 231195              15304                       1511
# 4691                 263601             137832                        191
# 4692                 166408              67980                        245
# 4693                 430953             185035                        233
# 4694                 139878              76942                        182
# 4695                 212506             102534                        207
# 4696                 140766              73438                        192
# 4697                 286305              81798                        350
# 4698                 228736              80667                        284
# 4699                 171003             113114                        151
# 4700                 287034             102784                        279
# 4701                 228678              51911                        441
# 4702                 189363              91758                        206
# 4703                 126790              11868                       1068
# 4704                 197076             135854                        145
# 4705                 201282             140952                        143
# 4706                 217470              66477                        327
# 4707                 285424             163208                        175
# 4708                 130849             120423                        109

# %% [markdown]
# <br>
# Altersstruktur der Stadt- und Landkreise in Ba-Wü
# https://www.statistik-bw.de/BevoelkGebiet/Alter/98015200.tab?R=KR237
#
# Download jeweils mittels des Amtlichen Gemeindeschlüssels (AGS)

# %%
# pbar = ProgressBar()

# AGS = ( pd.unique(data_inhab_perkm["Amtlicher Gemeindeschlüssel (AGS)"]) )%1000
# data_age = pd.DataFrame(columns = ["Jahr", "Unter20", "Über65", "20bis65", "AGS"])

# for ags in pbar(AGS):
#     temp_data = pd.read_csv("https://www.statistik-bw.de/BevoelkGebiet/Alter/98015200.tab?R=KR" + str(ags) + "&form=csv",
#                  encoding = "ISO-8859-1",
#                  sep=";",
#                  decimal=",",
#                  names = ["Jahr", "Unter20", "Über65", "20bis65"],
#                  usecols=[0,1,2,3],
#                  skiprows = 28,
#                  skipfooter = 20,
#                     engine='python')
#     temp_data["AGS"] = ags
#     data_age = data_age.append(temp_data, ignore_index=True)

# data_age["AGS"] = data_age["AGS"] + 8000

# data_age.to_csv("altersstruktur.csv", index = False)

# %%
data_age = pd.read_csv("altersstruktur.csv")
data_age
# Out:
#     Jahr  Unter20   Über65  20bis65   AGS
# 0   2020  109.680  113.716  421.919  8111
# 1   2021  109.892  114.218  423.461  8111
# 2   2020   78.538   80.109  236.644  8115
# 3   2021   78.881   81.539  236.339  8115
# 4   2020  101.883  111.712  325.572  8116
# ..   ...      ...      ...      ...   ...
# 83  2021   40.311   50.212  126.459  8435
# 84  2020   56.464   58.085  172.557  8436
# 85  2021   56.517   59.122  172.422  8436
# 86  2020   25.482   27.600   78.546  8437
# 87  2021   25.533   28.099   78.318  8437
#
# [88 rows x 5 columns]

# %%
data_age['Bevölkerung gesamt'] = data_age['Unter20'] + data_age['Über65'] + data_age['20bis65']
data_age['Ü65%'] = data_age['Über65']/ data_age['Bevölkerung gesamt'] 
data_age

#data_inhab_perkm1 = data_inhab_perkm.drop(['Kürzel der Regionaleinheit', 'Postleitzahl', 'Regionalname', 'Stichtag', 'Bevölkerung insgesamt', 'Gemeindegebiet ha'], axis = 1)
#data_inhab_perkm1

data_inhab['Ausländer%'] = data_inhab['Ausländer zusammen'].astype(int) / data_inhab['Bevölkerung insgesamt'].astype(int)
data_inhab = data_inhab.drop(['Kürzel der Regionaleinheit', 'Regionalname', 'Stichtag', 'Bevölkerung insgesamt', 'Bevölkerung männlich',\
                            'Bevölkerung weiblich', 'Deutsche männlich', 'Deutsche weiblich',\
                            'Deutsche zusammen', 'Ausländer zusammen', 'Ausländer männlich', 'Ausländer weiblich'], axis = 1)

# %%
data_age
# Out:
#     Jahr  Unter20   Über65  20bis65   AGS  Bevölkerung gesamt      Ü65%
# 0   2020  109.680  113.716  421.919  8111             645.315  0.176218
# 1   2021  109.892  114.218  423.461  8111             647.571  0.176379
# 2   2020   78.538   80.109  236.644  8115             395.291  0.202658
# 3   2021   78.881   81.539  236.339  8115             396.759  0.205513
# 4   2020  101.883  111.712  325.572  8116             539.167  0.207194
# ..   ...      ...      ...      ...   ...                 ...       ...
# 83  2021   40.311   50.212  126.459  8435             216.982  0.231411
# 84  2020   56.464   58.085  172.557  8436             287.106  0.202312
# 85  2021   56.517   59.122  172.422  8436             288.061  0.205241
# 86  2020   25.482   27.600   78.546  8437             131.628  0.209682
# 87  2021   25.533   28.099   78.318  8437             131.950  0.212952
#
# [88 rows x 7 columns]

# %%
data_all = data_all.merge(right= data_age, how = 'outer', right_on = 'AGS', left_on = 'IdLandkreis')
data_all2020 = data_all[(data_all["Meldedatum"].astype(str).str.contains(pat = '2020'))&
                        (data_all["Jahr"].astype(str).str.contains(pat = '2020'))]
data_all2021 = data_all[(data_all["Meldedatum"].astype(str).str.contains(pat = '2021'))&
                        (data_all["Jahr"].astype(str).str.contains(pat = '2021'))]
data_all = pd.concat([data_all2020, data_all2021])
data_all = data_all.drop(['Jahr', 'Unter20', 'Über65', '20bis65', 'AGS'], axis = 1)

data_all = data_all.merge(right = data_inhab, how = 'inner', right_on = 'Amtlicher Gemeindeschlüssel (AGS)', left_on = 'IdLandkreis')
data_all = data_all.drop(['Amtlicher Gemeindeschlüssel (AGS)'], axis = 1)
data_all = data_all.merge(right = data_inhab_perkm, how = 'inner', right_on = 'Amtlicher Gemeindeschlüssel (AGS)', left_on = 'IdLandkreis')
data_all = data_all.drop(['Amtlicher Gemeindeschlüssel (AGS)', 'Kürzel der Regionaleinheit', 'Postleitzahl', 'Regionalname',\
                          'Stichtag', 'Bevölkerung insgesamt', 'Gemeindegebiet ha'], axis = 1)

data_all["Bevölkerung gesamt"] = data_all["Bevölkerung gesamt"] * 1000
data_all["Bevölkerung gesamt"] = data_all["Bevölkerung gesamt"].astype(int)
data_all
# Out:
#       IdLandkreis Meldedatum  AnzahlFall  AnzahlGenesen  AnzahlFall>59  \
# 0            8111 2020-03-07           5              5              0
# 1            8111 2020-03-14          78             78              3
# 2            8111 2020-03-21         310            303             41
# 3            8111 2020-03-28         275            261             65
# 4            8111 2020-04-04         237            225             65
# ...           ...        ...         ...            ...            ...
# 2345         8437 2021-02-20          40             40             11
# 2346         8437 2021-02-27          80             78             14
# 2347         8437 2021-03-06         108             96             19
# 2348         8437 2021-03-13         161             37             22
# 2349         8437 2021-03-20         143              1             22
#
#            Landkreis  Bevölkerung gesamt      Ü65%  Ausländer%  \
# 0       SK Stuttgart              645315  0.176218    0.249539
# 1       SK Stuttgart              645315  0.176218    0.249539
# 2       SK Stuttgart              645315  0.176218    0.249539
# 3       SK Stuttgart              645315  0.176218    0.249539
# 4       SK Stuttgart              645315  0.176218    0.249539
# ...              ...                 ...       ...         ...
# 2345  LK Sigmaringen              131950  0.212952    0.113027
# 2346  LK Sigmaringen              131950  0.212952    0.113027
# 2347  LK Sigmaringen              131950  0.212952    0.113027
# 2348  LK Sigmaringen              131950  0.212952    0.113027
# 2349  LK Sigmaringen              131950  0.212952    0.113027
#
#       Bevölkerungsdichte EW/km²
# 0                          3067
# 1                          3067
# 2                          3067
# 3                          3067
# 4                          3067
# ...                         ...
# 2345                        109
# 2346                        109
# 2347                        109
# 2348                        109
# 2349                        109
#
# [2350 rows x 10 columns]

# %%
print("Klimadaten von der Station Ohlsbach (1602) - mittig von Baden-Württemberg")

request = DwdObservationRequest(
    parameter=[
        DwdObservationParameter.MONTHLY.TEMPERATURE_AIR_200
    ],
    resolution=DwdObservationResolution.MONTHLY,
    period=DwdObservationPeriod.RECENT,
).filter(station_id=(1602, ))

station_data = request.values.all().df

station_data.tail()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Klimadaten von der Station Ohlsbach (1602) - mittig von Baden-Württemberg
# 100%|██████████| 1/1 [00:00<00:00,  4.02it/s]
#    STATION_ID                 FROM_DATE          DATASET  \
# 14      01602 2020-10-01 00:00:00+00:00  CLIMATE_SUMMARY
# 15      01602 2020-11-01 00:00:00+00:00  CLIMATE_SUMMARY
# 16      01602 2020-12-01 00:00:00+00:00  CLIMATE_SUMMARY
# 17      01602 2021-01-01 00:00:00+00:00  CLIMATE_SUMMARY
# 18      01602 2021-02-01 00:00:00+00:00  CLIMATE_SUMMARY
#
#                      TO_DATE            PARAMETER  VALUE QUALITY
# 14 2020-10-31 00:00:00+00:00  TEMPERATURE_AIR_200  11.53       3
# 15 2020-11-30 00:00:00+00:00  TEMPERATURE_AIR_200   6.95       3
# 16 2020-12-31 00:00:00+00:00  TEMPERATURE_AIR_200   5.07       3
# 17 2021-01-31 00:00:00+00:00  TEMPERATURE_AIR_200   2.42       1
# 18 2021-02-28 00:00:00+00:00  TEMPERATURE_AIR_200   5.21       1

# %%
station_data.FROM_DATE = station_data.FROM_DATE.astype(str).str.slice(stop=7)
data_all["FROM_DATE"] = data_all.Meldedatum.astype(str).str.slice(stop=7)
station_data = station_data.drop(columns=["STATION_ID", "DATASET", "TO_DATE", "PARAMETER", "QUALITY"])

# %%
data_all = pd.merge(data_all, station_data, on="FROM_DATE")\
            .sort_values(['IdLandkreis', 'Meldedatum'])\
            .drop(columns=["FROM_DATE"])\
            .rename(columns={"VALUE": "Temperatur"})
data_all
# Out:
#       IdLandkreis Meldedatum  AnzahlFall  AnzahlGenesen  AnzahlFall>59  \
# 0            8111 2020-03-07           5              5              0
# 1            8111 2020-03-14          78             78              3
# 2            8111 2020-03-21         310            303             41
# 3            8111 2020-03-28         275            261             65
# 163          8111 2020-04-04         237            225             65
# ...           ...        ...         ...            ...            ...
# 2029         8437 2021-01-30         129            128             20
# 2202         8437 2021-02-06          93             93             11
# 2203         8437 2021-02-13          44             44              9
# 2204         8437 2021-02-20          40             40             11
# 2205         8437 2021-02-27          80             78             14
#
#            Landkreis  Bevölkerung gesamt      Ü65%  Ausländer%  \
# 0       SK Stuttgart              645315  0.176218    0.249539
# 1       SK Stuttgart              645315  0.176218    0.249539
# 2       SK Stuttgart              645315  0.176218    0.249539
# 3       SK Stuttgart              645315  0.176218    0.249539
# 163     SK Stuttgart              645315  0.176218    0.249539
# ...              ...                 ...       ...         ...
# 2029  LK Sigmaringen              131950  0.212952    0.113027
# 2202  LK Sigmaringen              131950  0.212952    0.113027
# 2203  LK Sigmaringen              131950  0.212952    0.113027
# 2204  LK Sigmaringen              131950  0.212952    0.113027
# 2205  LK Sigmaringen              131950  0.212952    0.113027
#
#       Bevölkerungsdichte EW/km²  Temperatur
# 0                          3067        7.49
# 1                          3067        7.49
# 2                          3067        7.49
# 3                          3067        7.49
# 163                        3067       13.72
# ...                         ...         ...
# 2029                        109        2.42
# 2202                        109        5.21
# 2203                        109        5.21
# 2204                        109        5.21
# 2205                        109        5.21
#
# [2218 rows x 11 columns]

# %% [markdown]
# <br>
#
# BIP Daten Download
#
# Letzter Datenstand: 2018
#
# BIP pro Kopf mit Bevölkerungszahlen von 2020. Für eine Schätzung ausreichend
#
# BIP Angabe in Mio. Deswegen BIP * 1000000

# %%
# pbar = ProgressBar()

# AGS = ( pd.unique(data_inhab_perkm["Amtlicher Gemeindeschlüssel (AGS)"]) )%1000
# data_bip = pd.DataFrame(columns = ["BIP", "AGS"])

# for ags in pbar(AGS):
#     condition = 0
#     while (condition < 1):
#         temp_data2 = pd.read_csv("https://www.statistik-bw.de/GesamtwBranchen/VGR/20013001.tab?R=KR" + str(ags) + "&form=csv",
#                      encoding = "ISO-8859-1",
#                      sep=";",
#                      decimal=",",
#                      names = ["BIP"],
#                      usecols=[1],
#                      skiprows = 33,
#                      skipfooter = 3,
#                         engine='python')
#         condition = temp_data2["BIP"].fillna(0).values[0]
        
#     temp_data2["AGS"] = ags
#     data_bip = data_bip.append(temp_data2, ignore_index=True)

# data_bip["AGS"] = data_bip["AGS"] + 8000
# data_bip["BIP"] = data_bip["BIP"] * 1000000
# data_bip["BIP"] = data_bip["BIP"].astype(int)
# data_bip.to_csv("bip.csv", index = False)

# %%
data_bip = pd.read_csv("bip.csv")
data_bip
# Out:
#          BIP   AGS
# 0   57369000  8111
# 1   25988000  8115
# 2   22779000  8116
# 3    8894000  8117
# 4   25522000  8118
# 5   15081000  8119
# 6    6993000  8121
# 7   19019000  8125
# 8    5676000  8126
# 9    8231000  8127
# 10   5260000  8128
# 11   4855000  8135
# 12  14088000  8136
# 13   3008000  8211
# 14  20475000  8212
# 15  16793000  8215
# 16  10213000  8216
# 17   9167000  8221
# 18  20921000  8222
# 19   4630000  8225
# 20  18763000  8226
# 21   5057000  8231
# 22   4625000  8235
# 23   6172000  8236
# 24   4715000  8237
# 25  11909000  8311
# 26   7921000  8315
# 27   5445000  8316
# 28  17657000  8317
# 29   6100000  8325
# 30   8513000  8326
# 31   7178000  8327
# 32   9990000  8335
# 33   7715000  8336
# 34   5323000  8337
# 35  11580000  8415
# 36   7709000  8416
# 37   6730000  8417
# 38   9725000  8421
# 39   6269000  8425
# 40  10517000  8426
# 41  11057000  8435
# 42  12798000  8436
# 43   5008000  8437

# %%
data_all = pd.merge(data_all, data_bip, left_on="IdLandkreis", right_on="AGS")\
            .sort_values(['IdLandkreis', 'Meldedatum'])\
            .drop(columns=["AGS"])
data_all["BIPK"] = data_all["BIP"]/data_all["Bevölkerung gesamt"]
data_all = data_all.drop(columns=["BIP"])
data_all
# Out:
#       IdLandkreis Meldedatum  AnzahlFall  AnzahlGenesen  AnzahlFall>59  \
# 0            8111 2020-03-07           5              5              0
# 1            8111 2020-03-14          78             78              3
# 2            8111 2020-03-21         310            303             41
# 3            8111 2020-03-28         275            261             65
# 4            8111 2020-04-04         237            225             65
# ...           ...        ...         ...            ...            ...
# 2213         8437 2021-01-30         129            128             20
# 2214         8437 2021-02-06          93             93             11
# 2215         8437 2021-02-13          44             44              9
# 2216         8437 2021-02-20          40             40             11
# 2217         8437 2021-02-27          80             78             14
#
#            Landkreis  Bevölkerung gesamt      Ü65%  Ausländer%  \
# 0       SK Stuttgart              645315  0.176218    0.249539
# 1       SK Stuttgart              645315  0.176218    0.249539
# 2       SK Stuttgart              645315  0.176218    0.249539
# 3       SK Stuttgart              645315  0.176218    0.249539
# 4       SK Stuttgart              645315  0.176218    0.249539
# ...              ...                 ...       ...         ...
# 2213  LK Sigmaringen              131950  0.212952    0.113027
# 2214  LK Sigmaringen              131950  0.212952    0.113027
# 2215  LK Sigmaringen              131950  0.212952    0.113027
# 2216  LK Sigmaringen              131950  0.212952    0.113027
# 2217  LK Sigmaringen              131950  0.212952    0.113027
#
#       Bevölkerungsdichte EW/km²  Temperatur       BIPK
# 0                          3067        7.49  88.900769
# 1                          3067        7.49  88.900769
# 2                          3067        7.49  88.900769
# 3                          3067        7.49  88.900769
# 4                          3067       13.72  88.900769
# ...                         ...         ...        ...
# 2213                        109        2.42  37.953770
# 2214                        109        5.21  37.953770
# 2215                        109        5.21  37.953770
# 2216                        109        5.21  37.953770
# 2217                        109        5.21  37.953770
#
# [2218 rows x 12 columns]

# %% [markdown]
# <br>
#
# Beschäftigte in Gastgewerbe & Gesundheits-/Sozialwesen (2020)
#
# https://www.statistik-bw.de/Arbeit/Beschaeftigte/0302317x.tab?R=KR111&form=csv
#
# <br>

# %%
data_all["BIPK"].astype(str)
# Out:
# 0       88.90076939169244
# 1       88.90076939169244
# 2       88.90076939169244
# 3       88.90076939169244
# 4       88.90076939169244
#               ...
# 2213    37.95377036756347
# 2214    37.95377036756347
# 2215    37.95377036756347
# 2216    37.95377036756347
# 2217    37.95377036756347
# Name: BIPK, Length: 2218, dtype: object

# %%
# pbar = ProgressBar()

# AGS = ( pd.unique(data_inhab_perkm["Amtlicher Gemeindeschlüssel (AGS)"]) )%1000
# data_besch = pd.DataFrame(columns = ["AGS", "Bgast", "Bgesund"])

# for ags in pbar(AGS):
#     condition = 0
#     while (condition < 1):
#         temp_data3 = pd.read_csv("https://www.statistik-bw.de/Arbeit/Beschaeftigte/0302317x.tab?R=KR" + str(ags) + "&form=csv",
#                      encoding = "ISO-8859-1",
#                      sep=";",
#                      decimal=",",
#                      names = ["TEMPCOL"],
#                      usecols=[2],
#                      skiprows = 12,
#                      skipfooter = 8,
#                      dtype = {
#                          "TEMPCOL": str
#                      },
#                      engine='python')
#         condition = temp_data3["TEMPCOL"].astype(float).fillna(0).values[4]
        
# data_besch["AGS"] = data_besch["AGS"] + 8000
# data_besch["Bgast"] = data_besch["Bgast"].str.replace(".", "")
# data_besch["Bgesund"] = data_besch["Bgesund"].str.replace(".", "")
# data_besch.to_csv("besch.csv", index = False)

# data_besch

# %%
data_besch = pd.read_csv("besch.csv")

# %%
data_all = pd.merge(data_all, data_besch, left_on="IdLandkreis", right_on="AGS")\
            .sort_values(['IdLandkreis', 'Meldedatum'])\
            .drop(columns=["AGS"])
data_all
# Out:
#       IdLandkreis Meldedatum  AnzahlFall  AnzahlGenesen  AnzahlFall>59  \
# 0            8111 2020-03-07           5              5              0
# 1            8111 2020-03-14          78             78              3
# 2            8111 2020-03-21         310            303             41
# 3            8111 2020-03-28         275            261             65
# 4            8111 2020-04-04         237            225             65
# ...           ...        ...         ...            ...            ...
# 2213         8437 2021-01-30         129            128             20
# 2214         8437 2021-02-06          93             93             11
# 2215         8437 2021-02-13          44             44              9
# 2216         8437 2021-02-20          40             40             11
# 2217         8437 2021-02-27          80             78             14
#
#            Landkreis  Bevölkerung gesamt      Ü65%  Ausländer%  \
# 0       SK Stuttgart              645315  0.176218    0.249539
# 1       SK Stuttgart              645315  0.176218    0.249539
# 2       SK Stuttgart              645315  0.176218    0.249539
# 3       SK Stuttgart              645315  0.176218    0.249539
# 4       SK Stuttgart              645315  0.176218    0.249539
# ...              ...                 ...       ...         ...
# 2213  LK Sigmaringen              131950  0.212952    0.113027
# 2214  LK Sigmaringen              131950  0.212952    0.113027
# 2215  LK Sigmaringen              131950  0.212952    0.113027
# 2216  LK Sigmaringen              131950  0.212952    0.113027
# 2217  LK Sigmaringen              131950  0.212952    0.113027
#
#       Bevölkerungsdichte EW/km²  Temperatur       BIPK  Bgast  Bgesund
# 0                          3067        7.49  88.900769  12014    47955
# 1                          3067        7.49  88.900769  12014    47955
# 2                          3067        7.49  88.900769  12014    47955
# 3                          3067        7.49  88.900769  12014    47955
# 4                          3067       13.72  88.900769  12014    47955
# ...                         ...         ...        ...    ...      ...
# 2213                        109        2.42  37.953770   1086     7365
# 2214                        109        5.21  37.953770   1086     7365
# 2215                        109        5.21  37.953770   1086     7365
# 2216                        109        5.21  37.953770   1086     7365
# 2217                        109        5.21  37.953770   1086     7365
#
# [2218 rows x 14 columns]

# %% [markdown]
# <br>
#
# Google Trends zur Suche "Corona" - Standarisiert von 0 - 100
#
# CSV Download über: https://trends.google.de/trends/explore?date=2020-01-01%202021-03-18&geo=DE-BW&q=Corona
#
# <br>

# %%
data_ggl = pd.read_csv("googleTrendsCorona.csv", skiprows = 2)\
            .rename(columns={"Corona: (Baden-Württemberg)": "GoogleCorona"})
data_ggl["Woche"] = pd.to_datetime(data_ggl["Woche"])
data_ggl["GoogleCorona"] = data_ggl["GoogleCorona"].replace(["<1"], 0)

# %%
data_all = pd.merge_asof(data_all.sort_values(['Meldedatum']), data_ggl, left_on="Meldedatum", right_on="Woche", direction="nearest")\
            .sort_values(['IdLandkreis', 'Meldedatum'])\
            .drop(columns=["Woche"])
data_all
# Out:
#       IdLandkreis Meldedatum  AnzahlFall  AnzahlGenesen  AnzahlFall>59  \
# 23           8111 2020-03-07           5              5              0
# 44           8111 2020-03-14          78             78              3
# 112          8111 2020-03-21         310            303             41
# 171          8111 2020-03-28         275            261             65
# 180          8111 2020-04-04         237            225             65
# ...           ...        ...         ...            ...            ...
# 2024         8437 2021-01-30         129            128             20
# 2082         8437 2021-02-06          93             93             11
# 2090         8437 2021-02-13          44             44              9
# 2141         8437 2021-02-20          40             40             11
# 2217         8437 2021-02-27          80             78             14
#
#            Landkreis  Bevölkerung gesamt      Ü65%  Ausländer%  \
# 23      SK Stuttgart              645315  0.176218    0.249539
# 44      SK Stuttgart              645315  0.176218    0.249539
# 112     SK Stuttgart              645315  0.176218    0.249539
# 171     SK Stuttgart              645315  0.176218    0.249539
# 180     SK Stuttgart              645315  0.176218    0.249539
# ...              ...                 ...       ...         ...
# 2024  LK Sigmaringen              131950  0.212952    0.113027
# 2082  LK Sigmaringen              131950  0.212952    0.113027
# 2090  LK Sigmaringen              131950  0.212952    0.113027
# 2141  LK Sigmaringen              131950  0.212952    0.113027
# 2217  LK Sigmaringen              131950  0.212952    0.113027
#
#       Bevölkerungsdichte EW/km²  Temperatur       BIPK  Bgast  Bgesund  \
# 23                         3067        7.49  88.900769  12014    47955
# 44                         3067        7.49  88.900769  12014    47955
# 112                        3067        7.49  88.900769  12014    47955
# 171                        3067        7.49  88.900769  12014    47955
# 180                        3067       13.72  88.900769  12014    47955
# ...                         ...         ...        ...    ...      ...
# 2024                        109        2.42  37.953770   1086     7365
# 2082                        109        5.21  37.953770   1086     7365
# 2090                        109        5.21  37.953770   1086     7365
# 2141                        109        5.21  37.953770   1086     7365
# 2217                        109        5.21  37.953770   1086     7365
#
#      GoogleCorona
# 23             73
# 44            100
# 112            74
# 171            59
# 180            46
# ...           ...
# 2024           27
# 2082           33
# 2090           27
# 2141           29
# 2217           38
#
# [2218 rows x 15 columns]

# %% [markdown]
# Berechnung der Inzidenz: AnzahlFall / Bevölkerung gesamt * 100.000
#
# Anteil der Genesenen pro Landkreis
#
# Anteil der Fälle > 59

# %%
data_all['7dInzidenz'] = data_all['AnzahlFall'] /  data_all['Bevölkerung gesamt'] * 100000
data_all['7dInzidenzFall>59'] = data_all['AnzahlFall>59'] / data_all['Bevölkerung gesamt'] * 100000
data_all['AnzahlFall>59%'] = data_all['AnzahlFall>59'] / data_all['AnzahlFall']

# %%
data_all['AnzahlGenesenLandkreis'] = data_all.groupby(['Landkreis'])['AnzahlGenesen'].cumsum()
data_all['AnzahlGenesenLandkreis%'] = data_all['AnzahlGenesenLandkreis'] / data_all['Bevölkerung gesamt']
data_all
# Out:
#       IdLandkreis Meldedatum  AnzahlFall  AnzahlGenesen  AnzahlFall>59  \
# 23           8111 2020-03-07           5              5              0
# 44           8111 2020-03-14          78             78              3
# 112          8111 2020-03-21         310            303             41
# 171          8111 2020-03-28         275            261             65
# 180          8111 2020-04-04         237            225             65
# ...           ...        ...         ...            ...            ...
# 2024         8437 2021-01-30         129            128             20
# 2082         8437 2021-02-06          93             93             11
# 2090         8437 2021-02-13          44             44              9
# 2141         8437 2021-02-20          40             40             11
# 2217         8437 2021-02-27          80             78             14
#
#            Landkreis  Bevölkerung gesamt      Ü65%  Ausländer%  \
# 23      SK Stuttgart              645315  0.176218    0.249539
# 44      SK Stuttgart              645315  0.176218    0.249539
# 112     SK Stuttgart              645315  0.176218    0.249539
# 171     SK Stuttgart              645315  0.176218    0.249539
# 180     SK Stuttgart              645315  0.176218    0.249539
# ...              ...                 ...       ...         ...
# 2024  LK Sigmaringen              131950  0.212952    0.113027
# 2082  LK Sigmaringen              131950  0.212952    0.113027
# 2090  LK Sigmaringen              131950  0.212952    0.113027
# 2141  LK Sigmaringen              131950  0.212952    0.113027
# 2217  LK Sigmaringen              131950  0.212952    0.113027
#
#       Bevölkerungsdichte EW/km²  Temperatur       BIPK  Bgast  Bgesund  \
# 23                         3067        7.49  88.900769  12014    47955
# 44                         3067        7.49  88.900769  12014    47955
# 112                        3067        7.49  88.900769  12014    47955
# 171                        3067        7.49  88.900769  12014    47955
# 180                        3067       13.72  88.900769  12014    47955
# ...                         ...         ...        ...    ...      ...
# 2024                        109        2.42  37.953770   1086     7365
# 2082                        109        5.21  37.953770   1086     7365
# 2090                        109        5.21  37.953770   1086     7365
# 2141                        109        5.21  37.953770   1086     7365
# 2217                        109        5.21  37.953770   1086     7365
#
#      GoogleCorona  7dInzidenz  7dInzidenzFall>59  AnzahlFall>59%  \
# 23             73    0.774815           0.000000        0.000000
# 44            100   12.087120           0.464889        0.038462
# 112            74   48.038555           6.353486        0.132258
# 171            59   42.614847          10.072600        0.236364
# 180            46   36.726250          10.072600        0.274262
# ...           ...         ...                ...             ...
# 2024           27   97.764305          15.157257        0.155039
# 2082           33   70.481243           8.336491        0.118280
# 2090           27   33.345964           6.820765        0.204545
# 2141           29   30.314513           8.336491        0.275000
# 2217           38   60.629026          10.610080        0.175000
#
#       AnzahlGenesenLandkreis  AnzahlGenesenLandkreis%
# 23                         5                 0.000008
# 44                        83                 0.000129
# 112                      386                 0.000598
# 171                      647                 0.001003
# 180                      872                 0.001351
# ...                      ...                      ...
# 2024                    2699                 0.020455
# 2082                    2792                 0.021160
# 2090                    2836                 0.021493
# 2141                    2876                 0.021796
# 2217                    2954                 0.022387
#
# [2218 rows x 20 columns]

# %% [markdown]
# <br>
# <span style="color:red">
#     Aufgabe:
# </span>
#
# - Inzidenz-Werte berechnen mit den Bevölkerungszahlen (Oben ist ein Link zum "Wie")
# - AnzahlFall>59 prozentual zu AnzahlFall = Fall>59
# - GenesenBevölkerung
#     - AnzahlGenesen zum Datum aufsummieren
#     - Prozentual zur Bevölkerung
#
# <br>

# %% [markdown]
# <br>
# <span style="color:red">
#     Aufgabe:
# </span>
#
# - Durchschnittliches Einkommen: Bruttolöhne https://www.statistik-bw.de/GesamtwBranchen/VGR/20023030.tab?R=KR111
# - Arbeitslosenquoten: https://www.statistik-bw.de/Arbeit/Arbeitslose/03033022.tab?R=KR111
# - Pflegebedürftige: https://www.statistik-bw.de/SozSicherung/Pflege/15163020.tab?R=KR111
#
# <br>

# %% [markdown]
# <br>
# <span style="color:red">
#     Aufgabe:
# </span>
#
# - Dummy Schulschließung
# - Dummy Gastro-Schließung
# - Anzahl private Versammlung
#     - Durchschnittlicher Haushalt + x
#     - Dokumentieren was wieso
# - Anzahl öffentliche Versammlung
# - Dummy Veranstaltungen
#     - Dokumentieren was das bedeutet
# - Dummy Maskenpflicht
# - Dummy Einzelhandel-Schließung
# - Dummy Ausgangssperre
#
#
# <br>

# %% [markdown]
# <br>
# <span style="color:red">
#     Aufgabe:
# </span>
#
# - Zwei Tabellen
#     - Eine Tabelle für Visualisierungen, Regressionsanalysen usw.
#     - Eine Tabelle standardisiert für Neuronales Netz
#
#
# <br>

# %% [markdown]
# <br>
# <span style="color:green">
#     Beispiele:
# </span>
#
# - https://www.kaggle.com/docxian/covid-19-tracking-germany
# - https://www.kaggle.com/mreverybody/covid19-germany-deutschland-rki-data
# - Beispiele für Tabellen-Manipulation: https://datascience-enthusiast.com/R/pandas_datatable.html
# -
